# %%
print('hello worlld')

# %%
print(7)
print(7.7)

# %%
print('hello',23,sep='/')
print('helo',end='-')
print('world')

# %%
#data types int
print(9)
print(1e308) #1 * 10^308 is the last and no 309
print(1e309)

# %%
#decimal 
print(9.66)
print(1.7e300)

# %%
#boolean
print(True) #case sensitive
print(False)

# %%
#text/ string 
print('hello world')
#complex
print(5+7j)

# %%
#list --> array in c 
print([3,4,5,6])
#tuple
print((2,3,4,5))

# %%
#sets
print({4,5,6,6})
#type
type(9.8)
type(8) #it is not prnted becas direct type keyword is used
print(type(4))

# %%
#static 
#normally like how we introduce data types 
#int a = 50;

# %%
input('apna naam bata')
input('enter email')

# %%
a=input("enter first number: ")
b=input("enter second number: ")
sum = a + b
print(sum)

# %%
a=int(input("enter first number: "))
b=int(input("enter second number: "))
sum = a + b
print('sum:',sum) 
print(type(a))
# Out:
# sum: 101
# <class 'int'>

# %%
#type conversion, does not changes the original data 
#implicit and explicit 
str(8)
float(8)
# Out:
# 8.0

# %%
#literals below is value 
a = 10 
#WHERE A IS THE VARIABLE 
#where = is the OPERATOR
# and 10 is the LITERALS

# %%
#there are many liyerals decimal .,float , int ets
